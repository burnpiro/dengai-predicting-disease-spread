# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import functools

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
# %matplotlib inline
pd.set_option("display.precision", 2)

# %%
#Generate dataset
def get_dataset(file_path, **kwargs):
  dataset = tf.data.experimental.make_csv_dataset(
      file_path,
      batch_size=5,
      na_value=None,
      num_epochs=1,
      ignore_errors=True, 
      **kwargs)
  return dataset

class PackNumericFeatures(object):
  def __init__(self, names):
    self.names = names

  def __call__(self, features, labels):
    numeric_features = [features.pop(name) for name in self.names]
    numeric_features = [tf.cast(feat, tf.float32) for feat in numeric_features]
    numeric_features = tf.stack(numeric_features, axis=-1)
    features['numeric'] = numeric_features

    return features, labels

def show_batch(dataset):
  for batch, label in dataset.take(1):
      print("'total cases': {}".format(label))
      print("features:")
      for key, value in batch.items():
        print("{:20s}: {}".format(key,value.numpy()))

# %%
LABEL_COLUMN = 'total_cases'
NUMERIC_COLUMNS = ['year',
                    'weekofyear',
                    'ndvi_ne',
                    'ndvi_nw',
                    'ndvi_se',
                    'ndvi_sw',
                    'precipitation_amt_mm',
                    'reanalysis_air_temp_k',
                    'reanalysis_avg_temp_k',
                    'reanalysis_dew_point_temp_k',
                    'reanalysis_max_air_temp_k',
                    'reanalysis_min_air_temp_k',
                    'reanalysis_precip_amt_kg_per_m2',
                    'reanalysis_relative_humidity_percent',
                    'reanalysis_sat_precip_amt_mm',
                    'reanalysis_specific_humidity_g_per_kg',
                    'reanalysis_tdtr_k',
                    'station_avg_temp_c',
                    'station_diur_temp_rng_c',
                    'station_max_temp_c',
                    'station_min_temp_c',
                    'station_precip_mm']
CATEGORICAL_COLUMNS = ['city']
CSV_COLUMNS = [LABEL_COLUMN] + CATEGORICAL_COLUMNS + NUMERIC_COLUMNS
CSV_COLUMNS_NO_LABEL = CATEGORICAL_COLUMNS + NUMERIC_COLUMNS
CATEGORIES = {
    'city': ['sj', 'iq']
}

NEW_COLUMNS = ['total_cases', 'year', 'weekofyear', 'station_avg_temp_c']

DATASET_SIZE = 1456
TRAIN_DATASET_FRAC = 0.8
train_file = './dengue_features_train_with_out.csv'

print(len(NEW_COLUMNS))
# Out:
# 4

# %%
#Get training dataset

def extract_data(train_file, columns):
    all_data = pd.read_csv(train_file, usecols = columns)
    # map categorical to columns
    for feature_name in CATEGORICAL_COLUMNS:
        mapping_dict = { CATEGORIES[feature_name][i] : CATEGORIES[feature_name][i] for i in range(0, len(CATEGORIES[feature_name]) ) }
        all_data[feature_name] = all_data[feature_name].map(mapping_dict)
    
    all_data = pd.get_dummies(all_data, prefix='', prefix_sep='')
    all_data = all_data.interpolate(method ='linear', limit_direction ='forward')
    
    return all_data

all_data = extract_data(train_file, CSV_COLUMNS)

# Split data into train and test
train_data = all_data.sample(frac=TRAIN_DATASET_FRAC,random_state=0)
test_data = all_data.drop(train_data.index)

print(len(train_data))
print(len(test_data))

train_y = train_data.pop(LABEL_COLUMN)
test_y = test_data.pop(LABEL_COLUMN)

# Display one batch from dataset
# show_batch(train_dataset)
train_data.head()
# Out:
# 1165
# 291
#      year  weekofyear  ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  \
# 511  2000           8     0.18     0.21     0.15     0.15
# 961  2000          51     0.27     0.17     0.23     0.30
# 231  1994          40     0.10     0.07     0.12     0.19
# 687  2003          29    -0.06    -0.11     0.22     0.19
# 34   1990          52     0.30     0.28     0.17     0.16
#
#      precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 511                  7.67                 297.09                 297.22
# 961                  3.90                 300.41                 302.00
# 231                  0.63                 300.38                 300.50
# 687                 62.57                 300.15                 300.34
# 34                   0.00                 298.04                 298.09
#
#      reanalysis_dew_point_temp_k  ...  reanalysis_sat_precip_amt_mm  \
# 511                       292.17  ...                          7.67
# 961                       291.09  ...                          3.90
# 231                       295.36  ...                          0.63
# 687                       296.32  ...                         62.57
# 34                        292.11  ...                          0.00
#
#      reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 511                                  13.67               1.99
# 961                                  13.19              13.00
# 231                                  16.74               2.63
# 687                                  17.72               1.91
# 34                                   13.68               2.29
#
#      station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 511               24.77                     6.63                28.3
# 961               28.20                    12.28                35.0
# 231               28.71                     6.90                34.4
# 687               27.47                     5.89                31.7
# 34                25.16                     5.84                28.9
#
#      station_min_temp_c  station_precip_mm  iq  sj
# 511                20.6                3.8   0   1
# 961                21.0                0.0   1   0
# 231                24.4                8.2   0   1
# 687                21.7               43.0   0   1
# 34                 21.1               20.9   0   1
#
# [5 rows x 24 columns]

# %%
train_stats = all_data.describe()
train_stats.pop(LABEL_COLUMN)
train_stats = train_stats.transpose()
train_stats
# Out:
#                                         count     mean    std      min  \
# year                                   1456.0  2001.03   5.41  1990.00
# weekofyear                             1456.0    26.50  15.02     1.00
# ndvi_ne                                1456.0     0.13   0.14    -0.41
# ndvi_nw                                1456.0     0.13   0.12    -0.46
# ndvi_se                                1456.0     0.20   0.07    -0.02
# ndvi_sw                                1456.0     0.20   0.08    -0.06
# precipitation_amt_mm                   1456.0    45.70  43.65     0.00
# reanalysis_air_temp_k                  1456.0   298.70   1.36   294.64
# reanalysis_avg_temp_k                  1456.0   299.22   1.26   294.89
# reanalysis_dew_point_temp_k            1456.0   295.24   1.53   289.64
# reanalysis_max_air_temp_k              1456.0   303.42   3.23   297.80
# reanalysis_min_air_temp_k              1456.0   295.72   2.56   286.90
# reanalysis_precip_amt_kg_per_m2        1456.0    40.13  43.31     0.00
# reanalysis_relative_humidity_percent   1456.0    82.17   7.15    57.79
# reanalysis_sat_precip_amt_mm           1456.0    45.70  43.65     0.00
# reanalysis_specific_humidity_g_per_kg  1456.0    16.74   1.54    11.72
# reanalysis_tdtr_k                      1456.0     4.90   3.54     1.36
# station_avg_temp_c                     1456.0    27.18   1.28    21.40
# station_diur_temp_rng_c                1456.0     8.10   2.13     4.53
# station_max_temp_c                     1456.0    32.45   1.96    26.70
# station_min_temp_c                     1456.0    22.10   1.57    14.70
# station_precip_mm                      1456.0    39.36  47.29     0.00
# iq                                     1456.0     0.36   0.48     0.00
# sj                                     1456.0     0.64   0.48     0.00
#
#                                            25%      50%      75%      max
# year                                   1997.00  2002.00  2005.00  2010.00
# weekofyear                               13.75    26.50    39.25    53.00
# ndvi_ne                                   0.04     0.12     0.23     0.51
# ndvi_nw                                   0.05     0.12     0.21     0.45
# ndvi_se                                   0.15     0.20     0.25     0.54
# ndvi_sw                                   0.14     0.19     0.25     0.55
# precipitation_amt_mm                      9.79    38.32    70.23   390.60
# reanalysis_air_temp_k                   297.66   298.64   299.83   302.20
# reanalysis_avg_temp_k                   298.26   299.29   300.21   302.93
# reanalysis_dew_point_temp_k             294.12   295.64   296.46   298.45
# reanalysis_max_air_temp_k               301.00   302.40   305.50   314.00
# reanalysis_min_air_temp_k               293.90   296.20   297.90   299.90
# reanalysis_precip_amt_kg_per_m2          13.20    27.30    52.20   570.50
# reanalysis_relative_humidity_percent     77.20    80.29    86.44    98.61
# reanalysis_sat_precip_amt_mm              9.79    38.32    70.23   390.60
# reanalysis_specific_humidity_g_per_kg    15.55    17.08    17.98    20.46
# reanalysis_tdtr_k                         2.33     2.86     7.63    16.03
# station_avg_temp_c                       26.31    27.40    28.13    30.80
# station_diur_temp_rng_c                   6.53     7.35     9.60    15.80
# station_max_temp_c                       31.10    32.80    33.90    42.20
# station_min_temp_c                       21.10    22.20    23.30    25.60
# station_precip_mm                         8.85    24.05    53.90   543.30
# iq                                        0.00     0.00     1.00     1.00
# sj                                        0.00     1.00     1.00     1.00

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler


cols_to_norm = ['precipitation_amt_mm',
                    'reanalysis_air_temp_k',
                    'reanalysis_avg_temp_k',
                    'reanalysis_dew_point_temp_k',
                    'reanalysis_max_air_temp_k',
                    'reanalysis_min_air_temp_k',
                    'reanalysis_precip_amt_kg_per_m2',
                    'reanalysis_relative_humidity_percent',
                    'reanalysis_sat_precip_amt_mm',
                    'reanalysis_specific_humidity_g_per_kg',
                    'reanalysis_tdtr_k',
                    'station_avg_temp_c',
                    'station_diur_temp_rng_c',
                    'station_max_temp_c',
                    'station_min_temp_c',
                    'station_precip_mm']
cols_to_scale = ['year',
                    'weekofyear']
def preproc_data(data):
    new_data = data.copy()
    # Normalize temp and percipation
    new_data[cols_to_norm] = StandardScaler().fit_transform(new_data[cols_to_norm])

    # Scale year and week no but within (0,1)
    new_data[cols_to_scale] = MinMaxScaler(feature_range=(0, 1)).fit_transform(new_data[cols_to_scale])
    
    return new_data

train_data = preproc_data(train_data)
all_y = all_data.pop(LABEL_COLUMN)
all_data = preproc_data(all_data)
test_data = preproc_data(test_data)
train_stats = train_data.describe()
train_stats = train_stats.transpose()
train_data.head()
# Out:
#      year  weekofyear  ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  \
# 511  0.50        0.13     0.18     0.21     0.15     0.15
# 961  0.50        0.96     0.27     0.17     0.23     0.30
# 231  0.20        0.75     0.10     0.07     0.12     0.19
# 687  0.65        0.54    -0.06    -0.11     0.22     0.19
# 34   0.00        0.98     0.30     0.28     0.17     0.16
#
#      precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 511                 -0.91                  -1.19                  -1.60
# 961                 -1.00                   1.27                   2.22
# 231                 -1.08                   1.25                   1.02
# 687                  0.46                   1.08                   0.90
# 34                  -1.10                  -0.49                  -0.91
#
#      reanalysis_dew_point_temp_k  ...  reanalysis_sat_precip_amt_mm  \
# 511                        -1.99  ...                         -0.91
# 961                        -2.70  ...                         -1.00
# 231                         0.09  ...                         -1.08
# 687                         0.71  ...                          0.46
# 34                         -2.03  ...                         -1.10
#
#      reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 511                                  -1.97              -0.83
# 961                                  -2.28               2.26
# 231                                   0.01              -0.65
# 687                                   0.64              -0.85
# 34                                   -1.97              -0.74
#
#      station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 511               -1.89                    -0.69               -2.10
# 961                0.79                     1.94                1.29
# 231                1.19                    -0.57                0.98
# 687                0.22                    -1.04               -0.38
# 34                -1.58                    -1.06               -1.80
#
#      station_min_temp_c  station_precip_mm  iq  sj
# 511               -0.97              -0.80   0   1
# 961               -0.71              -0.89   1   0
# 231                1.49              -0.69   0   1
# 687               -0.26               0.14   0   1
# 34                -0.65              -0.39   0   1
#
# [5 rows x 24 columns]

# %%
# Create input function

def input_fn(features, labels, training=True, batch_size=16):
    """An input function for training or evaluating"""
    # Convert the inputs to a Dataset.
    dataset = tf.data.Dataset.from_tensor_slices((dict(features), labels))

    # Shuffle and repeat if you are in training mode.
    if training:
        dataset = dataset.shuffle(100).repeat()
    
    return dataset.batch(batch_size)

# %%
# Build network with 
def build_model():
  model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=[len(train_data.keys())]),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1)
  ])

  optimizer = tf.keras.optimizers.Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999, amsgrad=False)

  model.compile(loss='mae',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
  return model

model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_43 (Dense)             (None, 64)                1600
# _________________________________________________________________
# dense_44 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_45 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 5,825
# Trainable params: 5,825
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the Model.
EPOCHS = 100

# The patience parameter is the amount of epochs to check for improvement
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=20)

history = model.fit(
  all_data, all_y,
  epochs=EPOCHS, validation_split = 0.2,
                    callbacks=[early_stop])
# Out:
# Train on 1164 samples, validate on 292 samples
# Epoch 1/100
# 1164/1164 [==============================] - 0s 368us/sample - loss: 21.9297 - mae: 21.9297 - mse: 2382.7051 - val_loss: 8.1533 - val_mae: 8.1533 - val_mse: 217.3480
# Epoch 2/100
# 1164/1164 [==============================] - 0s 146us/sample - loss: 20.0074 - mae: 20.0074 - mse: 2209.8291 - val_loss: 8.2453 - val_mae: 8.2453 - val_mse: 219.8994
# Epoch 3/100
# 1164/1164 [==============================] - 0s 159us/sample - loss: 19.4573 - mae: 19.4573 - mse: 2154.7458 - val_loss: 7.0248 - val_mae: 7.0248 - val_mse: 188.1801
# Epoch 4/100
# 1164/1164 [==============================] - 0s 166us/sample - loss: 19.0058 - mae: 19.0058 - mse: 2096.3240 - val_loss: 7.0901 - val_mae: 7.0901 - val_mse: 188.3158
# Epoch 5/100
# 1164/1164 [==============================] - 0s 157us/sample - loss: 19.1457 - mae: 19.1457 - mse: 2081.2722 - val_loss: 7.7993 - val_mae: 7.7993 - val_mse: 209.6761
# Epoch 6/100
# 1164/1164 [==============================] - 0s 170us/sample - loss: 18.4448 - mae: 18.4448 - mse: 2051.1541 - val_loss: 7.0155 - val_mae: 7.0155 - val_mse: 185.9421
# Epoch 7/100
# 1164/1164 [==============================] - 0s 155us/sample - loss: 18.4831 - mae: 18.4831 - mse: 2006.0299 - val_loss: 7.5163 - val_mae: 7.5163 - val_mse: 197.3855
# Epoch 8/100
# 1164/1164 [==============================] - 0s 166us/sample - loss: 18.3727 - mae: 18.3727 - mse: 2045.3492 - val_loss: 7.1343 - val_mae: 7.1343 - val_mse: 185.8210
# Epoch 9/100
# 1164/1164 [==============================] - 0s 162us/sample - loss: 18.1632 - mae: 18.1632 - mse: 1976.4027 - val_loss: 7.4223 - val_mae: 7.4223 - val_mse: 193.1508
# Epoch 10/100
# 1164/1164 [==============================] - 0s 158us/sample - loss: 18.1397 - mae: 18.1397 - mse: 2006.6290 - val_loss: 7.5168 - val_mae: 7.5168 - val_mse: 198.6826
# Epoch 11/100
# 1164/1164 [==============================] - 0s 155us/sample - loss: 17.9334 - mae: 17.9334 - mse: 1932.0084 - val_loss: 7.3219 - val_mae: 7.3219 - val_mse: 189.4643
# Epoch 12/100
# 1164/1164 [==============================] - 0s 174us/sample - loss: 17.7959 - mae: 17.7959 - mse: 1972.5673 - val_loss: 8.0556 - val_mae: 8.0556 - val_mse: 210.1568
# Epoch 13/100
# 1164/1164 [==============================] - 0s 161us/sample - loss: 17.8580 - mae: 17.8580 - mse: 1939.6626 - val_loss: 7.4850 - val_mae: 7.4850 - val_mse: 191.2197
# Epoch 14/100
# 1164/1164 [==============================] - 0s 165us/sample - loss: 17.6556 - mae: 17.6556 - mse: 1926.7229 - val_loss: 7.2343 - val_mae: 7.2343 - val_mse: 187.3066
# Epoch 15/100
# 1164/1164 [==============================] - 0s 151us/sample - loss: 17.7061 - mae: 17.7061 - mse: 1900.9326 - val_loss: 7.4062 - val_mae: 7.4062 - val_mse: 182.2248
# Epoch 16/100
# 1164/1164 [==============================] - 0s 157us/sample - loss: 17.4765 - mae: 17.4765 - mse: 1883.6924 - val_loss: 7.2112 - val_mae: 7.2112 - val_mse: 185.5080
# Epoch 17/100
# 1164/1164 [==============================] - 0s 168us/sample - loss: 17.3981 - mae: 17.3981 - mse: 1866.7738 - val_loss: 7.2908 - val_mae: 7.2908 - val_mse: 183.7364
# Epoch 18/100
# 1164/1164 [==============================] - 0s 162us/sample - loss: 17.2327 - mae: 17.2327 - mse: 1842.4633 - val_loss: 7.2524 - val_mae: 7.2524 - val_mse: 179.0786
# Epoch 19/100
# 1164/1164 [==============================] - 0s 159us/sample - loss: 17.2637 - mae: 17.2637 - mse: 1866.3522 - val_loss: 7.5013 - val_mae: 7.5013 - val_mse: 194.9189
# Epoch 20/100
# 1164/1164 [==============================] - 0s 161us/sample - loss: 17.0503 - mae: 17.0503 - mse: 1834.2805 - val_loss: 7.6287 - val_mae: 7.6287 - val_mse: 184.1947
# Epoch 21/100
# 1164/1164 [==============================] - 0s 163us/sample - loss: 17.0755 - mae: 17.0755 - mse: 1836.6632 - val_loss: 7.2916 - val_mae: 7.2916 - val_mse: 190.0547
# Epoch 22/100
# 1164/1164 [==============================] - 0s 158us/sample - loss: 17.1199 - mae: 17.1199 - mse: 1809.2893 - val_loss: 7.3381 - val_mae: 7.3381 - val_mse: 188.3499
# Epoch 23/100
# 1164/1164 [==============================] - 0s 154us/sample - loss: 16.9896 - mae: 16.9896 - mse: 1805.7805 - val_loss: 7.4716 - val_mae: 7.4716 - val_mse: 189.3690
# Epoch 24/100
# 1164/1164 [==============================] - 0s 152us/sample - loss: 16.8135 - mae: 16.8135 - mse: 1798.2378 - val_loss: 7.4853 - val_mae: 7.4853 - val_mse: 196.4532
# Epoch 25/100
# 1164/1164 [==============================] - 0s 155us/sample - loss: 16.9228 - mae: 16.9228 - mse: 1757.8616 - val_loss: 7.3520 - val_mae: 7.3520 - val_mse: 184.1055
# Epoch 26/100
# 1164/1164 [==============================] - 0s 163us/sample - loss: 16.8344 - mae: 16.8344 - mse: 1817.3286 - val_loss: 7.2927 - val_mae: 7.2927 - val_mse: 192.7116

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#      loss    mae      mse  val_loss  val_mae  val_mse  epoch
# 21  17.12  17.12  1809.29      7.34     7.34   188.35     21
# 22  16.99  16.99  1805.78      7.47     7.47   189.37     22
# 23  16.81  16.81  1798.24      7.49     7.49   196.45     23
# 24  16.92  16.92  1757.86      7.35     7.35   184.11     24
# 25  16.83  16.83  1817.33      7.29     7.29   192.71     25

# %%
loss, mae, mse = model.evaluate(test_data, test_y, verbose=2)

print("Testing set Mean Abs Error: {:5.2f} Total_cases".format(mae))
# Out:
# 291/291 - 0s - loss: 14.7511 - mae: 14.7511 - mse: 1694.1730
# Testing set Mean Abs Error: 14.75 Total_cases

# %%
test_predictions = model.predict(test_data).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_y, test_predictions)
plt.xlabel('True Values [Cases]')
plt.ylabel('Predictions [Cases]')
lims = [-10, 100]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims, lims)

# %%
# Get Test file and preprocess test data

test_file = './dengue_features_test.csv'

org_test_data = extract_data(test_file, CSV_COLUMNS_NO_LABEL)
proc_test_data = preproc_data(org_test_data)
proc_test_data.head()
# Out:
#    year  weekofyear   ndvi_ne  ndvi_nw  ndvi_se  ndvi_sw  \
# 0   0.0        0.33 -1.89e-02    -0.02     0.10     0.09
# 1   0.0        0.35 -1.80e-02    -0.01     0.08     0.07
# 2   0.0        0.37 -1.50e-03    -0.02     0.15     0.09
# 3   0.0        0.38  2.77e-02    -0.02     0.12     0.13
# 4   0.0        0.40  5.68e-02     0.04     0.06     0.08
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                  1.15                  -0.22              -6.13e-01
# 1                 -0.73                  -0.23              -6.08e-01
# 2                 -0.98                   0.44               6.04e-03
# 3                 -1.09                   0.60               2.91e-01
# 4                 -1.06                   0.66               2.47e-01
#
#    reanalysis_dew_point_temp_k  ...  reanalysis_sat_precip_amt_mm  \
# 0                        -0.58  ...                          1.15
# 1                        -0.67  ...                         -0.73
# 2                        -0.07  ...                         -0.98
# 3                        -0.66  ...                         -1.09
# 4                        -0.43  ...                         -1.06
#
#    reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# 0                                  -0.64              -0.56
# 1                                  -0.72              -0.72
# 2                                  -0.16              -0.19
# 3                                  -0.73              -0.22
# 4                                  -0.50              -0.44
#
#    station_avg_temp_c  station_diur_temp_rng_c  station_max_temp_c  \
# 0               -0.68                    -0.33                0.40
# 1               -1.05                    -0.94               -1.31
# 2                0.47                    -0.03                0.14
# 3                0.57                    -0.65                0.40
# 4                0.21                    -0.32                0.40
#
#    station_min_temp_c  station_precip_mm  iq  sj
# 0               -0.37               1.19   0   1
# 1               -0.08               0.01   0   1
# 2                0.27              -0.90   0   1
# 3                1.19              -0.97   0   1
# 4                0.56               1.45   0   1
#
# [5 rows x 24 columns]

# %%
test_predictions = model.predict(proc_test_data).flatten()

# %%
org_test_data = pd.read_csv(test_file)
org_test_data['total_cases'] = test_predictions
org_test_data['total_cases'] = org_test_data['total_cases'].apply(lambda x: int(x) if x > 0 else 0)
org_test_data[['city', 'year', 'weekofyear', 'total_cases']]
# Out:
#     city  year  weekofyear  total_cases
# 0     sj  2008          18           17
# 1     sj  2008          19           25
# 2     sj  2008          20           21
# 3     sj  2008          21           66
# 4     sj  2008          22           34
# ..   ...   ...         ...          ...
# 411   iq  2013          22            3
# 412   iq  2013          23            2
# 413   iq  2013          24            1
# 414   iq  2013          25            2
# 415   iq  2013          26            3
#
# [416 rows x 4 columns]

# %%
org_test_data[['city', 'year', 'weekofyear', 'total_cases']].to_csv('./out.csv', index=False)
